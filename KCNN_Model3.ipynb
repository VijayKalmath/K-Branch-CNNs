# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
# # Climate Change Satellite Image Classification Competition Model Submission Guide - keras
#
# ---
# **About the Original Data:**<br>
# *Data and Description accessed from [Tensorflow](https://www.tensorflow.org/datasets/catalog/bigearthnet)* <br>
# The BigEarthNet is a new large-scale Sentinel-2 benchmark archive, consisting of 590,326 Sentinel-2 image patches. The image patch size on the ground is 1.2 x 1.2 km with variable image size depending on the channel resolution. This is a multi-label dataset with 43 imbalanced labels, which has been simplified to single labels with 3 categories for the purposes of this competition.
#
# To construct the BigEarthNet, 125 Sentinel-2 tiles acquired between June 2017 and May 2018 over the 10 countries (Austria, Belgium, Finland, Ireland, Kosovo, Lithuania, Luxembourg, Portugal, Serbia, Switzerland) of Europe were initially selected. All the tiles were atmospherically corrected by the Sentinel-2 Level 2A product generation and formatting tool (sen2cor). Then, they were divided into 590,326 non-overlapping image patches. Each image patch was annotated by the multiple land-cover classes (i.e., multi-labels) that were provided from the CORINE Land Cover database of the year 2018 (CLC 2018).
#
# Bands and pixel resolution in meters:
#
#     B01: Coastal aerosol; 60m
#     B02: Blue; 10m
#     B03: Green; 10m
#     B04: Red; 10m
#     B05: Vegetation red edge; 20m
#     B06: Vegetation red edge; 20m
#     B07: Vegetation red edge; 20m
#     B08: NIR; 10m
#     B09: Water vapor; 60m
#     B11: SWIR; 20m
#     B12: SWIR; 20m
#     B8A: Narrow NIR; 20m
#
# License: Community Data License Agreement - Permissive, Version 1.0."
#
# **Competition Data Specifics:**<br>
# For the purpose of this competition, the original BigEarthNet dataset has been simplified to 20,000 images (15,000 training images and 5,000 test images) with 3 categories: "forest", "nonforest", and "snow_shadow_cloud", which contains images of snow and clouds. <br>
# Each "image" is a folder with 12 satellite image layers, each of which pics up on different features. The example preprocessor uses just three layers: B02, B03, and B04, which contain the standard RGB layers used in ML models. However, you are free to use any combination of the satellite image layers.
#
# **Data Source:**<br>
# Sumbul, G, Charfuelan, M, Demir, B and Markl, V. (2019). BigEarthNet: A Large-Scale Benchmark Archive For Remote Sensing Image Understanding. *Computing Research Repository (CoRR), abs/1902.06148.* https://www.tensorflow.org/datasets/catalog/bigearthnet

# %% [markdown]
# # Overview
# ---
#
# ![image.png](attachment:image.png)
#
#
# The K-Branch CNN is proposed to efficiently model the spatial and spectral content of RS images with a branchwise CNN architecture when the image bands are associated to different spatial resolutions (e.g., Sentinel-2 images).
#
#
# Excluding Bands01 and Bands09 - This is due to the fact these bands are mainly used for cloud screening, atmospheric correction and cirrus detection in RS applications and do not embody a significant amount of information for the characterization of semantic content of RS images

# %% [markdown]
# ## 1. Load Data

# %%
# !python -V
# Out:
# Python 3.8.0

# %%
#install aimodelshare library
# ! pip install aimodelshare-nightly

# %%
# Get competition data - May take a couple minutes due to size of data set
# from aimodelshare import download_data
# download_data('public.ecr.aws/y2e2a1d6/climate_competition_data-repository:latest')

# %%
# # Unzip Data - May take a couple minutes due to size of data set
# import zipfile
# with zipfile.ZipFile('climate_competition_data/climate_competition_data.zip', 'r') as zip_ref:
#     zip_ref.extractall('competition_data')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##2.   Preprocess data / Write and Save Preprocessor function

# %%
# Set up for data preprocessing
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
# Here is a pre-designed preprocessor, but you could also build your own to prepare the data differently

def preprocessor(imageband_directory):
    """
    This function preprocesses reads in images, resizes them to a fixed shape and
    min/max transforms them before converting feature values to float32 numeric values
    required by onnx files.

    params:
        imageband_directory
            path to folder with 13 satellite image bands

    returns:
        X
            numpy array of preprocessed image data

    """

    import PIL
    import os
    import numpy as np
    import tensorflow_datasets as tfds

    def _load_tif(data):
        """Loads TIF file and returns as float32 numpy array."""
        img = tfds.core.lazy_imports.PIL_Image.open(data)
        img = np.array(img.getdata()).reshape(img.size).astype(np.float32)
        return img

    def preprocess_image(imgarray): 
        return imgarray # First KNN Model , No Per Image Processing
    
    image_10M_resolution_list = [0]*4
    image_20M_resolution_list = [0]*6

    
    # 10m spatial resolution (bands 2, 3, 4, and 8 ) are fed into the first branch 
    # 20m spatial resolution (5, 6, 7, 8A, 11 and 12) are fed into the second branch.

    filelist1 = os.listdir(imageband_directory)

    for fpath in filelist1:
        fullpath = imageband_directory+"/"+fpath

        # 10m spatial resolution (bands 2, 3, 4, and 8 ) are fed into the first branch 
        #  B02 - Channel 0  
        #  B03 - Channel 1  
        #  B04 - Channel 2  
        #  B08 - Channel 3  
        if fullpath.endswith('B02.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_10M_resolution_list[0] = preprocess_image(imgarray)               

        if fullpath.endswith('B03.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_10M_resolution_list[1] = preprocess_image(imgarray)               
        
        if fullpath.endswith('B04.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_10M_resolution_list[2] = preprocess_image(imgarray)  
            
        if fullpath.endswith('B08.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_10M_resolution_list[3] = preprocess_image(imgarray)  

        # 20m spatial resolution (5, 6, 7, 8A, 11 and 12) are fed into the second branch.
        #  B05 - Channel 0  
        #  B06 - Channel 1  
        #  B07 - Channel 2  
        #  B8A - Channel 3 
        #  B11 - Channel 4
        #  B12 - Channel 5
        
        if fullpath.endswith('B05.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_20M_resolution_list[0] = preprocess_image(imgarray)               

        if fullpath.endswith('B06.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_20M_resolution_list[1] = preprocess_image(imgarray)               
        
        if fullpath.endswith('B07.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_20M_resolution_list[2] = preprocess_image(imgarray)  
            
        if fullpath.endswith('B8A.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_20M_resolution_list[3] = preprocess_image(imgarray)  
            
        if fullpath.endswith('B11.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_20M_resolution_list[4] = preprocess_image(imgarray)  
    
        if fullpath.endswith('B12.tif'): 
            imgarray = _load_tif(imageband_directory+"/"+fpath)
            image_20M_resolution_list[5] = preprocess_image(imgarray)  
        
    _10M_X = np.stack(image_10M_resolution_list, axis=2)   # to get (height,width,3)
    _20M_X = np.stack(image_20M_resolution_list, axis=2)
    
    # Expand dims to add "1" to object shape [1, h, w, channels] for keras model.
    _10M_X = np.expand_dims(_10M_X, axis=0)
    _20M_X = np.expand_dims(_20M_X, axis=0)

    _10M_X = np.array(_10M_X, dtype=np.float32) 
    _20M_X = np.array(_20M_X, dtype=np.float32)
    
    return _10M_X,_20M_X

# %%
# # Create complete list of file names
# forestfilenames = ["competition_data/trainingdata/forest/" +
#                    x for x in os.listdir("competition_data/trainingdata/forest")]
# nonforestfilenames = ["competition_data/trainingdata/nonforest/" +
#                       x for x in os.listdir("competition_data/trainingdata/nonforest")]
# otherfilenames = ["competition_data/trainingdata/other/" +
#                   x for x in os.listdir("competition_data/trainingdata/other")]

# filenames = forestfilenames+nonforestfilenames+otherfilenames


# preprocessed_image_data_10M = []
# preprocessed_image_data_20M = [] 


# for i in filenames:
#     try:
#         _10MX,_20MX  = preprocessor(i)
#         preprocessed_image_data_10M.append(_10MX)
#         preprocessed_image_data_20M.append(_20MX)
#     except Exception as e:
#         print(e)
#         pass

# %%
model_number = 3

# %%
# len(preprocessed_image_data_10M),len(preprocessed_image_data_20M)

# %%
# np.save(f"KCNN_{model_number}_10M",preprocessed_image_data_10M)
# np.save(f"KCNN_{model_number}_20M",preprocessed_image_data_20M)

# %%
preprocessed_image_data_10M = np.load(f"KCNN_{1}_10M.npy")
preprocessed_image_data_20M = np.load(f"KCNN_{1}_20M.npy")

# %%
# Set up y data
from itertools import repeat
forest=repeat("forest",5000)
nonforest=repeat("nonforest",5000)
other=repeat("snow_shadow_cloud",5000)
ylist=list(forest)+list(nonforest)+list(other)

# %%
# Shuffle X and y data
from sklearn.utils import shuffle

_10MX_train, _20MX_train , y_train = shuffle( 
                                                preprocessed_image_data_10M,
                                                preprocessed_image_data_20M, 
                                                ylist, 
                                                random_state = 42 )

# %%
_10MX_train=np.vstack(_10MX_train)

_20MX_train=np.vstack(_20MX_train)

# %%
_10MX_train.shape , _20MX_train.shape
# Out:
# ((15000, 120, 120, 4), (15000, 60, 60, 6))

# %%
_10MX_MaxValueArray = [] 
_20MX_MaxValueArray = [] 

for i in range(4):
    print(f"Max Value of {i} channel in _10MX is {_10MX_train[:,:,:,i].max()}")


for i in range(6):
    print(f"Max Value of {i} channel in _20MX is {_20MX_train[:,:,:,i].max()}")
# Out:
# Max Value of 0 channel in _10MX is 18581.0
# Max Value of 1 channel in _10MX is 17833.0
# Max Value of 2 channel in _10MX is 17032.0
# Max Value of 3 channel in _10MX is 16314.0
# Max Value of 0 channel in _20MX is 16685.0
# Max Value of 1 channel in _20MX is 16542.0
# Max Value of 2 channel in _20MX is 16395.0
# Max Value of 3 channel in _20MX is 16168.0
# Max Value of 4 channel in _20MX is 15350.0
# Max Value of 5 channel in _20MX is 15240.0

# %%
def divide_channelbyMax(X_train,val,max_ValueArray):
    for i in range(val): 
        max_ValueArray.append(X_train[:,:,:,i].max())
        X_train[:,:,:,i] = (X_train[:,:,:,i]*255)/max_ValueArray[-1]
    return X_train,max_ValueArray

# %%
_10MX_train,_10MX_MaxValueArray = divide_channelbyMax(_10MX_train,4,_10MX_MaxValueArray)


_20MX_train,_20MX_MaxValueArray = divide_channelbyMax(_20MX_train,6,_20MX_MaxValueArray)

# %%
_10MX_MaxValueArray,_20MX_MaxValueArray
# Out:
# ([18581.0, 17833.0, 17032.0, 16314.0],
#  [16685.0, 16542.0, 16395.0, 16168.0, 15350.0, 15240.0])

# %%
for i in range(4):
    print(f"Max Value of {i} channel in _10MX is {_10MX_train[:,:,:,i].max()}")


for i in range(6):
    print(f"Max Value of {i} channel in _20MX is {_20MX_train[:,:,:,i].max()}")
# Out:
# Max Value of 0 channel in _10MX is 255.0
# Max Value of 1 channel in _10MX is 255.0
# Max Value of 2 channel in _10MX is 255.0
# Max Value of 3 channel in _10MX is 255.0
# Max Value of 0 channel in _20MX is 255.0
# Max Value of 1 channel in _20MX is 255.0
# Max Value of 2 channel in _20MX is 255.0
# Max Value of 3 channel in _20MX is 255.0
# Max Value of 4 channel in _20MX is 255.0
# Max Value of 5 channel in _20MX is 255.0

# %%
_10MX_train.shape , _20MX_train.shape
# Out:
# ((15000, 120, 120, 4), (15000, 60, 60, 6))

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from tensorflow.keras.models import Model

from tensorflow.keras.layers import Input,Conv2D,Dense,BatchNormalization,Flatten,Activation,ReLU
from tensorflow.keras.layers import concatenate,Dropout,MaxPooling2D,GlobalAveragePooling2D

from tensorflow.keras.optimizers import SGD

from tensorflow.keras.applications.resnet import ResNet50


from tensorflow.keras.utils import plot_model

import pandas 


os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
#   def branch_model_10m(self, inputs, is_training):
#         with tf.variable_scope('CNN_10m_branch'):
#             out = self.conv_block(inputs, 32, [5,5], is_training, 'conv_block_0')
#             out = self.pooling(out, 'max_pooling')
#             out = self.dropout(out, 0.25, is_training, 'dropout_0')
#             out = self.conv_block(out, 32, [5,5], is_training, 'conv_block_1')
#             out = self.pooling(out, 'max_pooling_1')
#             out = self.dropout(out, 0.25, is_training, 'dropout_1')
#             out = self.conv_block(out, 64, [3,3], is_training, 'conv_block_2')
#             out = self.dropout(out, 0.25, is_training, 'dropout_2')
#             out = tf.contrib.layers.flatten(out)
#             out = self.fully_connected_block(out, self.feature_size, is_training, 'fc_block_0')
#             feature = self.dropout(out, 0.5, is_training, 'dropout_3')
#             return feature 

#     def branch_model_20m(self, inputs, is_training):
#         with tf.variable_scope('CNN_20m_branch'):
#             out = self.conv_block(inputs, 32, [3,3], is_training, 'conv_block_0')
#             out = self.pooling(out, 'max_pooling_0')
#             out = self.dropout(out, 0.25, is_training, 'dropout_0')
#             out = self.conv_block(out, 32, [3,3], is_training, 'conv_block_1')
#             out = self.dropout(out, 0.25, is_training, 'dropout_1')
#             out = self.conv_block(out, 64, [3,3], is_training, 'conv_block_2')
#             out = self.dropout(out, 0.25, is_training, 'dropout_2')
#             out = tf.contrib.layers.flatten(out)
#             out = self.fully_connected_block(out, self.feature_size, is_training, 'fc_block_0')
#             feature = self.dropout(out, 0.5, is_training, 'dropout_3')  
#             return feature

# %%
def ConvolutionBlock(inputs,filter_size,nb_filter):
    output = Conv2D(filter_size,nb_filter)(inputs)
    batch_norm = BatchNormalization()(output)
    relu_output = ReLU()(batch_norm)
    return relu_output

def FullyConnectedBlock(inputs,nb_neurons):
    output = Dense(nb_neurons)(inputs)
    batch_norm = BatchNormalization()(output)
    relu_output = ReLU()(batch_norm)
    return relu_output

_10MX_Input = Input(shape=(120, 120, 4))

_10MX = ConvolutionBlock(_10MX_Input, 32, (20,20))
_10MX = MaxPooling2D()(_10MX)
_10MX = Dropout(0.25)(_10MX)
_10MX = ConvolutionBlock(_10MX, 32, (5,5))
_10MX = MaxPooling2D()(_10MX)
_10MX = Dropout(0.25)(_10MX)
_10MX = ConvolutionBlock(_10MX, 64, (3,3))
_10MX = Dropout(0.25)(_10MX)
_10MX = Flatten()(_10MX)
_10MX = FullyConnectedBlock(_10MX,128)
_10MX = Dropout(0.5)(_10MX)


_20MX_Input = Input(shape=(60, 60, 6))

_20MX = ConvolutionBlock(_20MX_Input, 32, (10,10))
_20MX = MaxPooling2D()(_20MX)
_20MX = Dropout(0.25)(_20MX)
_20MX = ConvolutionBlock(_20MX, 32, (3,3))
_20MX = Dropout(0.25)(_20MX)
_20MX = ConvolutionBlock(_20MX, 64, (3,3))
_20MX = Dropout(0.25)(_20MX)
_20MX = Flatten()(_20MX)
_20MX = FullyConnectedBlock(_20MX,128)
_20MX = Dropout(0.5)(_20MX)


Concat_layer = concatenate([_10MX,_20MX])

X = FullyConnectedBlock(Concat_layer,128)
X = Dropout(0.2)(X)
X = FullyConnectedBlock(X,1024)
X = Dropout(0.2)(X)
X = FullyConnectedBlock(X,512)
X = Dropout(0.2)(X)
X = Dense(3, activation='softmax')(X)

model = Model(inputs=[_10MX_Input,_20MX_Input], outputs= X)
plot_model(model)
# model.summary()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 120, 120, 4  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 101, 101, 32  51232       ['input_1[0][0]']
#                                 )
#
#  input_2 (InputLayer)           [(None, 60, 60, 6)]  0           []
#
#  batch_normalization (BatchNorm  (None, 101, 101, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 51, 51, 32)   19232       ['input_2[0][0]']
#
#  re_lu (ReLU)                   (None, 101, 101, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 51, 51, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 50, 50, 32)   0           ['re_lu[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 51, 51, 32)   0           ['batch_normalization_4[0][0]']
#
#  dropout (Dropout)              (None, 50, 50, 32)   0           ['max_pooling2d[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 32)  0           ['re_lu_4[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 46, 46, 32)   25632       ['dropout[0][0]']
#
#  dropout_4 (Dropout)            (None, 25, 25, 32)   0           ['max_pooling2d_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 46, 46, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 23, 23, 32)   9248        ['dropout_4[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 46, 46, 32)   0           ['batch_normalization_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 23, 23, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 23, 23, 32)  0           ['re_lu_1[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 23, 23, 32)   0           ['batch_normalization_5[0][0]']
#
#  dropout_1 (Dropout)            (None, 23, 23, 32)   0           ['max_pooling2d_1[0][0]']
#
#  dropout_5 (Dropout)            (None, 23, 23, 32)   0           ['re_lu_5[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 21, 21, 64)   18496       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 21, 21, 64)   18496       ['dropout_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 21, 21, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 21, 21, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 21, 21, 64)   0           ['batch_normalization_2[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 21, 21, 64)   0           ['batch_normalization_6[0][0]']
#
#  dropout_2 (Dropout)            (None, 21, 21, 64)   0           ['re_lu_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 21, 21, 64)   0           ['re_lu_6[0][0]']
#
#  flatten (Flatten)              (None, 28224)        0           ['dropout_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 28224)        0           ['dropout_6[0][0]']
#
#  dense (Dense)                  (None, 128)          3612800     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 128)          3612800     ['flatten_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 128)         512         ['dense[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 128)         512         ['dense_1[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 128)          0           ['batch_normalization_3[0][0]']
#
#  re_lu_7 (ReLU)                 (None, 128)          0           ['batch_normalization_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['re_lu_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 128)          0           ['re_lu_7[0][0]']
#
#  concatenate (Concatenate)      (None, 256)          0           ['dropout_3[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  dense_2 (Dense)                (None, 128)          32896       ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 128)         512         ['dense_2[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 128)          0           ['batch_normalization_8[0][0]']
#
#  dropout_8 (Dropout)            (None, 128)          0           ['re_lu_8[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         132096      ['dropout_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 1024)        4096        ['dense_3[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 1024)         0           ['batch_normalization_9[0][0]']
#
#  dropout_9 (Dropout)            (None, 1024)         0           ['re_lu_9[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dropout_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 512)         2048        ['dense_4[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 512)          0           ['batch_normalization_10[0][0]']
#
#  dropout_10 (Dropout)           (None, 512)          0           ['re_lu_10[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_10[0][0]']
#
# ==================================================================================================
# Total params: 8,067,971
# Trainable params: 8,063,619
# Non-trainable params: 4,352
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(5e-4),
                      metrics=['accuracy'])

def scheduler(epoch, lr):
    if epoch < 5 :
        return lr
    else:
        return lr * tf.math.exp(-0.5)
    
Model_Checkpoint = tf.keras.callbacks.ModelCheckpoint(f"KCNN_Model{model_number}",save_best_only=True)
    
    
Learningrate_Scheduler  = tf.keras.callbacks.LearningRateScheduler(scheduler)
    
with tf.device('/device:GPU:0'): # "/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.
    model.fit(  [_10MX_train , _20MX_train], 
                pandas.get_dummies(y_train),
                validation_split = .3, 
                epochs = 10,
                callbacks=[Model_Checkpoint,Learningrate_Scheduler])
    

    model.save(f"KCNN_Model{model_number}.h5")
# Out:
# Epoch 1/10
# 329/329 [==============================] - ETA: 0s - loss: 0.6405 - accuracy: 0.7234
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# 329/329 [==============================] - 42s 95ms/step - loss: 0.6405 - accuracy: 0.7234 - val_loss: 0.8324 - val_accuracy: 0.6144 - lr: 5.0000e-04
# Epoch 2/10
# 328/329 [============================>.] - ETA: 0s - loss: 0.5037 - accuracy: 0.7833
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# 329/329 [==============================] - 29s 87ms/step - loss: 0.5039 - accuracy: 0.7833 - val_loss: 0.6880 - val_accuracy: 0.7011 - lr: 5.0000e-04
# Epoch 3/10
# 328/329 [============================>.] - ETA: 0s - loss: 0.4760 - accuracy: 0.7970
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# 329/329 [==============================] - 28s 86ms/step - loss: 0.4761 - accuracy: 0.7970 - val_loss: 0.6193 - val_accuracy: 0.7076 - lr: 5.0000e-04
# Epoch 4/10
# 329/329 [==============================] - 21s 65ms/step - loss: 0.4405 - accuracy: 0.8136 - val_loss: 0.6260 - val_accuracy: 0.7476 - lr: 5.0000e-04
# Epoch 5/10
# 328/329 [============================>.] - ETA: 0s - loss: 0.4225 - accuracy: 0.8170
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# 329/329 [==============================] - 28s 86ms/step - loss: 0.4228 - accuracy: 0.8169 - val_loss: 0.5000 - val_accuracy: 0.7742 - lr: 5.0000e-04
# Epoch 6/10
# 328/329 [============================>.] - ETA: 0s - loss: 0.4057 - accuracy: 0.8277
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# 329/329 [==============================] - 29s 88ms/step - loss: 0.4060 - accuracy: 0.8276 - val_loss: 0.3686 - val_accuracy: 0.8436 - lr: 3.0327e-04
# Epoch 7/10
# 329/329 [==============================] - 22s 66ms/step - loss: 0.3716 - accuracy: 0.8404 - val_loss: 0.3724 - val_accuracy: 0.8278 - lr: 1.8394e-04
# Epoch 8/10
# 329/329 [==============================] - 21s 65ms/step - loss: 0.3507 - accuracy: 0.8476 - val_loss: 0.3780 - val_accuracy: 0.8178 - lr: 1.1157e-04
# Epoch 9/10
# 328/329 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.8555
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# INFO:tensorflow:Assets written to: KCNN_Model3/assets
# 329/329 [==============================] - 29s 87ms/step - loss: 0.3362 - accuracy: 0.8554 - val_loss: 0.3360 - val_accuracy: 0.8456 - lr: 6.7668e-05
# Epoch 10/10
# 329/329 [==============================] - 21s 65ms/step - loss: 0.3296 - accuracy: 0.8561 - val_loss: 0.3442 - val_accuracy: 0.8347 - lr: 4.1043e-05

# %% [markdown]
# ###  Test Image Preprocessing

# %%
# filenumbers = [str(x) for x in range(1, 5001)]

# filenames = ["competition_data/testdata/test/test"+x for x in filenumbers]


# preprocessed_image_data_10M = []
# preprocessed_image_data_20M = [] 


# for i in filenames:
#     try:
#         _10MX,_20MX  = preprocessor(i)
#         preprocessed_image_data_10M.append(_10MX)
#         preprocessed_image_data_20M.append(_20MX)
#     except Exception as e:
#         print(e)
#         pass

# %%
# np.save(f"KCNN_test{model_number}_10M",preprocessed_image_data_10M)
# np.save(f"KCNN_test{model_number}_20M",preprocessed_image_data_20M)

preprocessed_image_data_10M = np.load(f"KCNN_test{1}_10M.npy")
preprocessed_image_data_20M = np.load(f"KCNN_test{1}_20M.npy")

# %%
_10MX_test=np.vstack(preprocessed_image_data_10M)

_20MX_test=np.vstack(preprocessed_image_data_20M)

# %%
_10MX_test.shape , _20MX_test.shape
# Out:
# ((5000, 120, 120, 4), (5000, 60, 60, 6))

# %%
for i in range(4):
    print(f"Max Value of {i} channel in _10MX is {_10MX_test[:,:,:,i].max()}")

for i in range(6):
    print(f"Max Value of {i} channel in _20MX is {_20MX_test[:,:,:,i].max()}")
# Out:
# Max Value of 0 channel in _10MX is 20565.0
# Max Value of 1 channel in _10MX is 18913.0
# Max Value of 2 channel in _10MX is 17842.0
# Max Value of 3 channel in _10MX is 16586.0
# Max Value of 0 channel in _20MX is 17374.0
# Max Value of 1 channel in _20MX is 16929.0
# Max Value of 2 channel in _20MX is 16693.0
# Max Value of 3 channel in _20MX is 16391.0
# Max Value of 4 channel in _20MX is 15429.0
# Max Value of 5 channel in _20MX is 15261.0

# %%
def divide_TestchannelbyMax(X_train,val,max_ValueArray):
    for i in range(val): 
        X_train[:,:,:,i] = (X_train[:,:,:,i]*255)/max_ValueArray[i]
    return X_train

# %%
_10MX_test,_ = divide_channelbyMax(_10MX_test,4,_10MX_MaxValueArray)


_20MX_test,_ = divide_channelbyMax(_20MX_test,6,_20MX_MaxValueArray)

# %%
for i in range(4):
    print(f"Max Value of {i} channel in _10MX is {_10MX_test[:,:,:,i].max()}")


for i in range(6):
    print(f"Max Value of {i} channel in _20MX is {_20MX_test[:,:,:,i].max()}")
# Out:
# Max Value of 0 channel in _10MX is 255.0
# Max Value of 1 channel in _10MX is 255.0
# Max Value of 2 channel in _10MX is 255.0
# Max Value of 3 channel in _10MX is 255.0
# Max Value of 0 channel in _20MX is 255.0
# Max Value of 1 channel in _20MX is 255.0
# Max Value of 2 channel in _20MX is 255.0
# Max Value of 3 channel in _20MX is 255.0
# Max Value of 4 channel in _20MX is 255.0
# Max Value of 5 channel in _20MX is 255.0

# %%
_10MX_test.shape , _20MX_test.shape
# Out:
# ((5000, 120, 120, 4), (5000, 60, 60, 6))

# %%
prediction_column_index=model.predict([_10MX_test,_20MX_test]).argmax(axis=1)
# Out:
# 157/157 [==============================] - 3s 17ms/step

# %%
prediction_column_index
# Out:
# array([1, 0, 1, ..., 0, 1, 0])

# %%
prediction_labels = [pandas.get_dummies(y_train).columns[i] for i in prediction_column_index]

# %%
prediction_labels
# Out:
# ['nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'snow_shadow_cloud',
#  'nonforest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'forest',
#  'forest',
#  'nonforest',
#  'forest',
#  'forest',
#  'forest',
#  'nonforest',
#  'nonforest',
#  'nonforest',
#  ...]

# %%
np.save(f"KCNN_test{model_number}_Prediction_labels",prediction_labels)

# %%
old = np.load(f"KCNN_test{1}_Prediction_labels.npy")

# %%
(old == prediction_labels).sum()/len(prediction_labels)
# Out:
# 0.8738

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# cannot pickle 'module' object
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# /home/ecbm4040/climate_change/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /usr/lib/python3.8/runpy.py:125: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2022-03-26 06:24:26,421 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2022-03-26 06:24:28,676 - INFO - Signatures found in model: [serving_default].
# 2022-03-26 06:24:28,676 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2022-03-26 06:24:28,677 - INFO - Output names: ['dense_5']
# WARNING:tensorflow:From /home/ecbm4040/climate_change/lib/python3.8/site-packages/tf2onnx/tf_loader.py:706: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-03-26 06:24:29,647 - WARNING - From /home/ecbm4040/climate_change/lib/python3.8/site-packages/tf2onnx/tf_loader.py:706: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# 2022-03-26 06:24:30,069 - INFO - Using tensorflow=2.9.0-dev20220319, onnx=1.11.0, tf2onnx=1.9.3/1190aa
# 2022-03-26 06:24:30,069 - INFO - Using opset <onnx, 13>
# 2022-03-26 06:24:32,112 - INFO - Computed 0 values for constant folding
# 2022-03-26 06:24:33,382 - INFO - Optimizing ONNX model
# 2022-03-26 06:24:33,677 - INFO - After optimization: BatchNormalization -6 (6->0), Cast -2 (2->0), Const -26 (61->35), Identity -17 (17->0), Transpose -26 (30->4)
# 2022-03-26 06:24:33,716 - INFO -
# 2022-03-26 06:24:33,717 - INFO - Successfully converted TensorFlow model /tmp/tmp6co4_www to ONNX
# 2022-03-26 06:24:33,717 - INFO - Model inputs: ['input_1', 'input_2']
# 2022-03-26 06:24:33,717 - INFO - Model outputs: ['dense_5']
# 2022-03-26 06:24:33,717 - INFO - ONNX model is saved at /tmp/tmp6co4_www/temp.onnx

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

# Note -- This is the unique rest api that powers this climate change image classification  Model Plaground
# ... Update the apiurl if submitting to a new competition

apiurl="https://srdmat3yhf.execute-api.us-east-1.amazonaws.com/prod/m"
set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:········
# AI Modelshare Password:········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition

mycompetition= ai.Competition(apiurl)

# %%
# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
#  19% [..........                                          ]  2760704 / 14048690
# 100% [....................................................] 14048690 / 14048690
# /home/ecbm4040/climate_change/lib/python3.8/site-packages/aimodelshare/model.py:287: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /home/ecbm4040/climate_change/lib/python3.8/site-packages/aimodelshare/model.py:289: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /home/ecbm4040/climate_change/lib/python3.8/site-packages/aimodelshare/model.py:290: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /home/ecbm4040/climate_change/lib/python3.8/site-packages/aimodelshare/model.py:291: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# 100% [........................................................] 775866 / 775866
# /home/ecbm4040/climate_change/lib/python3.8/site-packages/aimodelshare/model.py:287: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 191
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1535

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_77849_row0_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 84.4%, transparent 84.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_77849_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 80.8%, transparent 80.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_77849_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 84.4%, transparent 84.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_77849_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 82.3%, transparent 82.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_77849_row0_col4, #T_77849_row0_col5, #T_77849_row0_col6, #T_77849_row0_col7, #T_77849_row0_col8, #T_77849_row0_col9, #T_77849_row0_col10, #T_77849_row0_col11, #T_77849_row0_col12, #T_77849_row0_col13, #T_77849_row0_col14, #T_77849_row0_col15, #T_77849_row0_col16, #T_77849_row0_col17, #T_77849_row0_col18, #T_77849_row0_col19, #T_77849_row0_col20, #T_77849_row0_col21, #T_77849_row0_col22, #T_77849_row0_col23, #T_77849_row0_col24, #T_77849_row0_col25, #T_77849_row0_col26, #T_77849_row0_col27, #T_77849_row0_col28, #T_77849_row0_col29, #T_77849_row0_col30, #T_77849_row0_col31, #T_77849_row0_col32, #T_77849_row0_col33, #T_77849_row0_col34, #T_77849_row0_col35, #T_77849_row0_col36, #T_77849_row0_col37, #T_77849_row0_col38, #T_77849_row0_col39, #T_77849_row0_col40, #T_77849_row0_col41, #T_77849_row0_col42, #T_77849_row0_col43, #T_77849_row0_col44, #T_77849_row0_col45, #T_77849_row0_col46, #T_77849_row0_col47, #T_77849_row0_col48, #T_77849_row0_col49, #T_77849_row0_col50, #T_77849_row0_col51, #T_77849_row0_col52, #T_77849_row1_col4, #T_77849_row1_col5, #T_77849_row1_col6, #T_77849_row1_col7, #T_77849_row1_col8, #T_77849_row1_col9, #T_77849_row1_col10, #T_77849_row1_col11, #T_77849_row1_col12, #T_77849_row1_col13, #T_77849_row1_col14, #T_77849_row1_col15, #T_77849_row1_col16, #T_77849_row1_col17, #T_77849_row1_col18, #T_77849_row1_col19, #T_77849_row1_col20, #T_77849_row1_col21, #T_77849_row1_col22, #T_77849_row1_col23, #T_77849_row1_col24, #T_77849_row1_col25, #T_77849_row1_col26, #T_77849_row1_col27, #T_77849_row1_col28, #T_77849_row1_col29, #T_77849_row1_col30, #T_77849_row1_col31, #T_77849_row1_col32, #T_77849_row1_col33, #T_77849_row1_col34, #T_77849_row1_col35, #T_77849_row1_col36, #T_77849_row1_col37, #T_77849_row1_col38, #T_77849_row1_col39, #T_77849_row1_col40, #T_77849_row1_col41, #T_77849_row1_col42, #T_77849_row1_col43, #T_77849_row1_col44, #T_77849_row1_col45, #T_77849_row1_col46, #T_77849_row1_col47, #T_77849_row1_col48, #T_77849_row1_col49, #T_77849_row1_col50, #T_77849_row1_col51, #T_77849_row1_col52, #T_77849_row2_col4, #T_77849_row2_col5, #T_77849_row2_col6, #T_77849_row2_col7, #T_77849_row2_col8, #T_77849_row2_col9, #T_77849_row2_col10, #T_77849_row2_col11, #T_77849_row2_col12, #T_77849_row2_col13, #T_77849_row2_col14, #T_77849_row2_col15, #T_77849_row2_col16, #T_77849_row2_col17, #T_77849_row2_col18, #T_77849_row2_col19, #T_77849_row2_col20, #T_77849_row2_col21, #T_77849_row2_col22, #T_77849_row2_col23, #T_77849_row2_col24, #T_77849_row2_col25, #T_77849_row2_col26, #T_77849_row2_col27, #T_77849_row2_col28, #T_77849_row2_col29, #T_77849_row2_col30, #T_77849_row2_col31, #T_77849_row2_col32, #T_77849_row2_col33, #T_77849_row2_col34, #T_77849_row2_col35, #T_77849_row2_col36, #T_77849_row2_col37, #T_77849_row2_col38, #T_77849_row2_col39, #T_77849_row2_col40, #T_77849_row2_col41, #T_77849_row2_col42, #T_77849_row2_col43, #T_77849_row2_col44, #T_77849_row2_col45, #T_77849_row2_col46, #T_77849_row2_col47, #T_77849_row2_col48, #T_77849_row2_col49, #T_77849_row2_col50, #T_77849_row2_col51, #T_77849_row2_col52, #T_77849_row3_col4, #T_77849_row3_col5, #T_77849_row3_col6, #T_77849_row3_col7, #T_77849_row3_col8, #T_77849_row3_col9, #T_77849_row3_col10, #T_77849_row3_col11, #T_77849_row3_col12, #T_77849_row3_col13, #T_77849_row3_col14, #T_77849_row3_col15, #T_77849_row3_col16, #T_77849_row3_col17, #T_77849_row3_col18, #T_77849_row3_col19, #T_77849_row3_col20, #T_77849_row3_col21, #T_77849_row3_col22, #T_77849_row3_col23, #T_77849_row3_col24, #T_77849_row3_col25, #T_77849_row3_col26, #T_77849_row3_col27, #T_77849_row3_col28, #T_77849_row3_col29, #T_77849_row3_col30, #T_77849_row3_col31, #T_77849_row3_col32, #T_77849_row3_col33, #T_77849_row3_col34, #T_77849_row3_col35, #T_77849_row3_col36, #T_77849_row3_col37, #T_77849_row3_col38, #T_77849_row3_col39, #T_77849_row3_col40, #T_77849_row3_col41, #T_77849_row3_col42, #T_77849_row3_col43, #T_77849_row3_col44, #T_77849_row3_col45, #T_77849_row3_col46, #T_77849_row3_col47, #T_77849_row3 ...

# %%
data[data["username"] == "vkalmath"]
# Out:
#      accuracy  f1_score  precision    recall ml_framework transfer_learning  \
# 4      0.7648  0.776539   0.791213  0.827111        keras               NaN
# 8      0.7600  0.750484   0.798412  0.787111        keras               NaN
# 26     0.7276  0.725968   0.722002  0.785111        keras               NaN
# 35     0.6972  0.709685   0.722674  0.756667        keras               NaN
# 40     0.6964  0.698332   0.749256  0.724222        keras               NaN
# 49     0.6676  0.677101   0.775917  0.726889        keras               NaN
# 76     0.6792  0.669706   0.672293  0.696000        keras               NaN
# 77     0.6840  0.641584   0.727566  0.649778        keras              True
# 82     0.6504  0.638267   0.715933  0.673333        keras               NaN
# 91     0.6436  0.630026   0.718117  0.666000        keras               NaN
# 182    0.3828  0.407672   0.461674  0.508222        keras               NaN
# 197    0.3916  0.387116   0.427798  0.353556        keras               NaN
# 213    0.2000  0.111111   0.066667  0.333333        keras               NaN
# 215    0.1940  0.114698   0.069714  0.323333        keras               NaN
#
#     deep_learning  model_type  depth  num_params  ...  memory_size  Member1  \
# 4            True  Sequential    8.0    136387.0  ...    4813664.0      NaN
# 8            True  Functional    6.0   4721667.0  ...   36292024.0      NaN
# 26           True  Sequential    7.0    136387.0  ...    4803824.0      NaN
# 35           True  Sequential    7.0  20057603.0  ...   27253624.0      NaN
# 40           True  Sequential    8.0   9573891.0  ...   14168312.0      NaN
# 49           True  Functional   42.0   8067971.0  ...    6403824.0      NaN
# 76           True  Sequential    8.0   9573891.0  ...   14116664.0      NaN
# 77           True  Sequential    7.0    136387.0  ...    4803824.0      NaN
# 82           True  Sequential   11.0   5288963.0  ...    4938160.0      NaN
# 91           True  Sequential   11.0   5288963.0  ...    4938160.0      NaN
# 182          True  Sequential    7.0   9573891.0  ...   14105328.0      NaN
# 197          True  Sequential    8.0   1847811.0  ...    2114800.0      NaN
# 213          True  Sequential    8.0   2102467.0  ...   15819488.0      NaN
# 215          True  Sequential    8.0   2102467.0  ...   15819488.0      NaN
#
#      Member2  team  Deep Learning  Optimizer  Transfer Learning  username  \
# 4        NaN   NaN            NaN        NaN                NaN  vkalmath
# 8        NaN   NaN            NaN        NaN                NaN  vkalmath
# 26       NaN   NaN            NaN        NaN                NaN  vkalmath
# 35       NaN   NaN            NaN        NaN                NaN  vkalmath
# 40       NaN   NaN            NaN        NaN                NaN  vkalmath
# 49       NaN   NaN            NaN        NaN                NaN  vkalmath
# 76       NaN   NaN            NaN        NaN                NaN  vkalmath
# 77       NaN   NaN            NaN        NaN                NaN  vkalmath
# 82       NaN   NaN            NaN        NaN                NaN  vkalmath
# 91       NaN   NaN            NaN        NaN                NaN  vkalmath
# 182      NaN   NaN            NaN        NaN                NaN  vkalmath
# 197      NaN   NaN            NaN        NaN                NaN  vkalmath
# 213      NaN   NaN            NaN        NaN                NaN  vkalmath
# 215      NaN   NaN            NaN        NaN                NaN  vkalmath
#
#                       timestamp  version
# 4    2022-03-19 19:11:33.485952       88
# 8    2022-03-25 03:05:21.678937      170
# 26   2022-03-18 19:48:55.382639       73
# 35   2022-03-24 03:19:52.050337      153
# 40   2022-03-24 01:39:59.262445      152
# 49   2022-03-26 06:26:15.381972      191
# 76   2022-03-21 19:46:29.959795      120
# 77   2022-03-17 22:32:37.060508       64
# 82   2022-03-19 23:06:22.545450       91
# 91   2022-03-19 23:22:15.864357       92
# 182  2022-03-23 20:42:09.766975      145
# 197  2022-03-17 18:58:03.360045       59
# 213  2022-03-24 16:32:52.591178      161
# 215  2022-03-24 16:27:46.431216      160
#
# [14 rows x 58 columns]

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard
#
# *Train and submit your own models using code modeled after what you see above.*

# %% [markdown]
# It may also be useful to examine the architeture of models that perform particuarly well/poorly, or to compare models you've created with similar models submitted by others. Use the compare_models function in combination with the leaderboard to learn more about models that been previously submitted and potentially make decisiona about what you should do next.

# %%
# Compare two or more models
data=mycompetition.compare_models([1, 5], verbose=1)
mycompetition.stylize_compare(data)
